# %% [markdown]
# ## Notebook setup

# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dependencies

# %%
# !pip install -r "/content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from -r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 1)) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from -r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 2)) (1.21.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from -r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 3)) (3.2.2)
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 15.0 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from -r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 5)) (1.0.2)
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.7 MB/s
# Collecting pytorch-lightning==1.7.7
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
#      |████████████████████████████████| 708 kB 60.0 MB/s
# Collecting aitextgen
#   Downloading aitextgen-0.6.0.tar.gz (572 kB)
#      |████████████████████████████████| 572 kB 64.5 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#      |████████████████████████████████| 529 kB 57.2 MB/s
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (6.0)
# Requirement already satisfied: torch>=1.9.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.12.1+cu113)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (21.3)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (2022.11.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (4.64.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (2.9.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (4.1.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (3.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (2.23.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (2.14.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (3.19.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (57.4.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.50.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (0.38.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (5.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning==1.7.7->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 7)) (3.2.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 1)) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 3)) (0.11.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 70.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 4)) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 4)) (3.8.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 55.4 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 5)) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 5)) (3.1.0)
# Collecting fire>=0.3.0
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 8.4 MB/s
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire>=0.3.0->aitextgen->-r /content/drive/MyDrive/ml_projects/tdt12_nlp_creative/requirements.txt (line 8)) (2.1.0)
# Building wheels for collected packages: aitextgen, fire
#   Building wheel for aitextgen (setup.py) ... done
#   Created wheel for aitextgen: filename=aitextgen-0.6.0-py3-none-any.whl size=576010 sha256=219d222a758d19d2cf9c33e4d380b4e68e3a0177f857f7b388c2f25d5c4a8ec6
#   Stored in directory: /root/.cache/pip/wheels/eb/77/2a/993dcd2bf690ff75db487709aa0f770f15ea57a7f8ed088524
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=a35f95e77572c9c1e02723e54aeeed047b36f10dbb3acda71f75184efae7afb4
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built aitextgen fire
# Installing collected packages: torchmetrics, tokenizers, pyDeprecate, huggingface-hub, transformers, pytorch-lightning, fire, demoji, aitextgen
# Successfully installed aitextgen-0.6.0 demoji-1.1.0 fire-0.4.0 huggingface-hub-0.11.0 pyDeprecate-0.3.2 pytorch-lightning-1.7.7 tokenizers-0.13.2 torchmetrics-0.10.3 transformers-4.24.0

# %% [markdown]
# ### Python Imports

# %%
# File/string operations
DATA = "/content/drive/MyDrive/ml_projects/tdt12_nlp_creative"
import shutil
import os
# Logging
import logging
logging.basicConfig(
        format="%(asctime)s — %(levelname)s — %(name)s — %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO
    )
# Model operations
from aitextgen import aitextgen

# %% [markdown]
# ### Verify active GPU in Colab

# %%
# !nvidia-smi
# Out:
# Wed Nov 23 16:31:29 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Load TokenDataset

# %%
file_name = "dataset_cache.tar.gz"
shutil.copy(f"{DATA}/dataset/{file_name}", f"./{file_name}")
# Out:
# './dataset_cache.tar.gz'

# %% [markdown]
# ## Model fine-tuning

# %% [markdown]
# ### Load Model

# %% [markdown]
# There are several sizes of GPT-2:
#
# * `124M` (default): the "small" model, 500MB on disk.
# * `355M` (default): the "medium" model, 1.5GB on disk.
# * `774M` (default): the "large" model, 3GB on disk.
#
# You can also finetune a GPT Neo model instead, which is more suitable for longer texts and the base model has more recent data:
#
# * `125M`: Analogous to the GPT-2 124M model.
# * `350M`: Analogous to the GPT-2 355M model
#
# The next cell downloads the model and saves it in the Colaboratory VM. If the model has already been downloaded, running this cell will reload it.

# %%
ai = aitextgen(tf_gpt2="355M", to_gpu=True)

# Comment out the above line and uncomment the below line to use GPT Neo instead.
# ai = aitextgen(model="EleutherAI/gpt-neo-125M", to_gpu=True)
# Out:
# INFO:aitextgen:Downloading the 355M GPT-2 TensorFlow weights/config from Google's servers
# Fetching checkpoint:   0%|          | 0.00/77.0 [00:00<?, ?it/s]
# Fetching hparams.json:   0%|          | 0.00/91.0 [00:00<?, ?it/s]
# Fetching model.ckpt.data-00000-of-00001:   0%|          | 0.00/1.42G [00:00<?, ?it/s]
# Fetching model.ckpt.index:   0%|          | 0.00/10.4k [00:00<?, ?it/s]
# Fetching model.ckpt.meta:   0%|          | 0.00/927k [00:00<?, ?it/s]
# INFO:aitextgen:Converting the 355M GPT-2 TensorFlow weights to PyTorch.
# Converting TensorFlow checkpoint from /content/aitextgen/355M
# Loading TF weight model/h0/attn/c_attn/b with shape [3072]
# Loading TF weight model/h0/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h0/attn/c_proj/b with shape [1024]
# Loading TF weight model/h0/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h0/ln_1/b with shape [1024]
# Loading TF weight model/h0/ln_1/g with shape [1024]
# Loading TF weight model/h0/ln_2/b with shape [1024]
# Loading TF weight model/h0/ln_2/g with shape [1024]
# Loading TF weight model/h0/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h0/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h0/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h0/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h1/attn/c_attn/b with shape [3072]
# Loading TF weight model/h1/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h1/attn/c_proj/b with shape [1024]
# Loading TF weight model/h1/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h1/ln_1/b with shape [1024]
# Loading TF weight model/h1/ln_1/g with shape [1024]
# Loading TF weight model/h1/ln_2/b with shape [1024]
# Loading TF weight model/h1/ln_2/g with shape [1024]
# Loading TF weight model/h1/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h1/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h1/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h1/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h10/attn/c_attn/b with shape [3072]
# Loading TF weight model/h10/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h10/attn/c_proj/b with shape [1024]
# Loading TF weight model/h10/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h10/ln_1/b with shape [1024]
# Loading TF weight model/h10/ln_1/g with shape [1024]
# Loading TF weight model/h10/ln_2/b with shape [1024]
# Loading TF weight model/h10/ln_2/g with shape [1024]
# Loading TF weight model/h10/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h10/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h10/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h10/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h11/attn/c_attn/b with shape [3072]
# Loading TF weight model/h11/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h11/attn/c_proj/b with shape [1024]
# Loading TF weight model/h11/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h11/ln_1/b with shape [1024]
# Loading TF weight model/h11/ln_1/g with shape [1024]
# Loading TF weight model/h11/ln_2/b with shape [1024]
# Loading TF weight model/h11/ln_2/g with shape [1024]
# Loading TF weight model/h11/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h11/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h11/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h11/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h12/attn/c_attn/b with shape [3072]
# Loading TF weight model/h12/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h12/attn/c_proj/b with shape [1024]
# Loading TF weight model/h12/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h12/ln_1/b with shape [1024]
# Loading TF weight model/h12/ln_1/g with shape [1024]
# Loading TF weight model/h12/ln_2/b with shape [1024]
# Loading TF weight model/h12/ln_2/g with shape [1024]
# Loading TF weight model/h12/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h12/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h12/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h12/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h13/attn/c_attn/b with shape [3072]
# Loading TF weight model/h13/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h13/attn/c_proj/b with shape [1024]
# Loading TF weight model/h13/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h13/ln_1/b with shape [1024]
# Loading TF weight model/h13/ln_1/g with shape [1024]
# Loading TF weight model/h13/ln_2/b with shape [1024]
# Loading TF weight model/h13/ln_2/g with shape [1024]
# Loading TF weight model/h13/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h13/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h13/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h13/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h14/attn/c_attn/b with shape [3072]
# Loading TF weight model/h14/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h14/attn/c_proj/b with shape [1024]
# Loading TF weight model/h14/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h14/ln_1/b with shape [1024]
# Loading TF weight model/h14/ln_1/g with shape [1024]
# Loading TF weight model/h14/ln_2/b with shape [1024]
# Loading TF weight model/h14/ln_2/g with shape [1024]
# Loading TF weight model/h14/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h14/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h14/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h14/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h15/attn/c_attn/b with shape [3072]
# Loading TF weight model/h15/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h15/attn/c_proj/b with shape [1024]
# Loading TF weight model/h15/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h15/ln_1/b with shape [1024]
# Loading TF weight model/h15/ln_1/g with shape [1024]
# Loading TF weight model/h15/ln_2/b with shape [1024]
# Loading TF weight model/h15/ln_2/g with shape [1024]
# Loading TF weight model/h15/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h15/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h15/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h15/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h16/attn/c_attn/b with shape [3072]
# Loading TF weight model/h16/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h16/attn/c_proj/b with shape [1024]
# Loading TF weight model/h16/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h16/ln_1/b with shape [1024]
# Loading TF weight model/h16/ln_1/g with shape [1024]
# Loading TF weight model/h16/ln_2/b with shape [1024]
# Loading TF weight model/h16/ln_2/g with shape [1024]
# Loading TF weight model/h16/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h16/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h16/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h16/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h17/attn/c_attn/b with shape [3072]
# Loading TF weight model/h17/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h17/attn/c_proj/b with shape [1024]
# Loading TF weight model/h17/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h17/ln_1/b with shape [1024]
# Loading TF weight model/h17/ln_1/g with shape [1024]
# Loading TF weight model/h17/ln_2/b with shape [1024]
# Loading TF weight model/h17/ln_2/g with shape [1024]
# Loading TF weight model/h17/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h17/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h17/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h17/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h18/attn/c_attn/b with shape [3072]
# Loading TF weight model/h18/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h18/attn/c_proj/b with shape [1024]
# Loading TF weight model/h18/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h18/ln_1/b with shape [1024]
# Loading TF weight model/h18/ln_1/g with shape [1024]
# Loading TF weight model/h18/ln_2/b with shape [1024]
# Loading TF weight model/h18/ln_2/g with shape [1024]
# Loading TF weight model/h18/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h18/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h18/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h18/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h19/attn/c_attn/b with shape [3072]
# Loading TF weight model/h19/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h19/attn/c_proj/b with shape [1024]
# Loading TF weight model/h19/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h19/ln_1/b with shape [1024]
# Loading TF weight model/h19/ln_1/g with shape [1024]
# Loading TF weight model/h19/ln_2/b with shape [1024]
# Loading TF weight model/h19/ln_2/g with shape [1024]
# Loading TF weight model/h19/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h19/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h19/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h19/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h2/attn/c_attn/b with shape [3072]
# Loading TF weight model/h2/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h2/attn/c_proj/b with shape [1024]
# Loading TF weight model/h2/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h2/ln_1/b with shape [1024]
# Loading TF weight model/h2/ln_1/g with shape [1024]
# Loading TF weight model/h2/ln_2/b with shape [1024]
# Loading TF weight model/h2/ln_2/g with shape [1024]
# Loading TF weight model/h2/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h2/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h2/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h2/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h20/attn/c_attn/b with shape [3072]
# Loading TF weight model/h20/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h20/attn/c_proj/b with shape [1024]
# Loading TF weight model/h20/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h20/ln_1/b with shape [1024]
# Loading TF weight model/h20/ln_1/g with shape [1024]
# Loading TF weight model/h20/ln_2/b with shape [1024]
# Loading TF weight model/h20/ln_2/g with shape [1024]
# Loading TF weight model/h20/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h20/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h20/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h20/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h21/attn/c_attn/b with shape [3072]
# Loading TF weight model/h21/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h21/attn/c_proj/b with shape [1024]
# Loading TF weight model/h21/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h21/ln_1/b with shape [1024]
# Loading TF weight model/h21/ln_1/g with shape [1024]
# Loading TF weight model/h21/ln_2/b with shape [1024]
# Loading TF weight model/h21/ln_2/g with shape [1024]
# Loading TF weight model/h21/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h21/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h21/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h21/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h22/attn/c_attn/b with shape [3072]
# Loading TF weight model/h22/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h22/attn/c_proj/b with shape [1024]
# Loading TF weight model/h22/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h22/ln_1/b with shape [1024]
# Loading TF weight model/h22/ln_1/g with shape [1024]
# Loading TF weight model/h22/ln_2/b with shape [1024]
# Loading TF weight model/h22/ln_2/g with shape [1024]
# Loading TF weight model/h22/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h22/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h22/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h22/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h23/attn/c_attn/b with shape [3072]
# Loading TF weight model/h23/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h23/attn/c_proj/b with shape [1024]
# Loading TF weight model/h23/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h23/ln_1/b with shape [1024]
# Loading TF weight model/h23/ln_1/g with shape [1024]
# Loading TF weight model/h23/ln_2/b with shape [1024]
# Loading TF weight model/h23/ln_2/g with shape [1024]
# Loading TF weight model/h23/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h23/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h23/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h23/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h3/attn/c_attn/b with shape [3072]
# Loading TF weight model/h3/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h3/attn/c_proj/b with shape [1024]
# Loading TF weight model/h3/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h3/ln_1/b with shape [1024]
# Loading TF weight model/h3/ln_1/g with shape [1024]
# Loading TF weight model/h3/ln_2/b with shape [1024]
# Loading TF weight model/h3/ln_2/g with shape [1024]
# Loading TF weight model/h3/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h3/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h3/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h3/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h4/attn/c_attn/b with shape [3072]
# Loading TF weight model/h4/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h4/attn/c_proj/b with shape [1024]
# Loading TF weight model/h4/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h4/ln_1/b with shape [1024]
# Loading TF weight model/h4/ln_1/g with shape [1024]
# Loading TF weight model/h4/ln_2/b with shape [1024]
# Loading TF weight model/h4/ln_2/g with shape [1024]
# Loading TF weight model/h4/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h4/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h4/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h4/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h5/attn/c_attn/b with shape [3072]
# Loading TF weight model/h5/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h5/attn/c_proj/b with shape [1024]
# Loading TF weight model/h5/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h5/ln_1/b with shape [1024]
# Loading TF weight model/h5/ln_1/g with shape [1024]
# Loading TF weight model/h5/ln_2/b with shape [1024]
# Loading TF weight model/h5/ln_2/g with shape [1024]
# Loading TF weight model/h5/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h5/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h5/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h5/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h6/attn/c_attn/b with shape [3072]
# Loading TF weight model/h6/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h6/attn/c_proj/b with shape [1024]
# Loading TF weight model/h6/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h6/ln_1/b with shape [1024]
# Loading TF weight model/h6/ln_1/g with shape [1024]
# Loading TF weight model/h6/ln_2/b with shape [1024]
# Loading TF weight model/h6/ln_2/g with shape [1024]
# Loading TF weight model/h6/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h6/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h6/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h6/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h7/attn/c_attn/b with shape [3072]
# Loading TF weight model/h7/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h7/attn/c_proj/b with shape [1024]
# Loading TF weight model/h7/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h7/ln_1/b with shape [1024]
# Loading TF weight model/h7/ln_1/g with shape [1024]
# Loading TF weight model/h7/ln_2/b with shape [1024]
# Loading TF weight model/h7/ln_2/g with shape [1024]
# Loading TF weight model/h7/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h7/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h7/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h7/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h8/attn/c_attn/b with shape [3072]
# Loading TF weight model/h8/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h8/attn/c_proj/b with shape [1024]
# Loading TF weight model/h8/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h8/ln_1/b with shape [1024]
# Loading TF weight model/h8/ln_1/g with shape [1024]
# Loading TF weight model/h8/ln_2/b with shape [1024]
# Loading TF weight model/h8/ln_2/g with shape [1024]
# Loading TF weight model/h8/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h8/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h8/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h8/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/h9/attn/c_attn/b with shape [3072]
# Loading TF weight model/h9/attn/c_attn/w with shape [1, 1024, 3072]
# Loading TF weight model/h9/attn/c_proj/b with shape [1024]
# Loading TF weight model/h9/attn/c_proj/w with shape [1, 1024, 1024]
# Loading TF weight model/h9/ln_1/b with shape [1024]
# Loading TF weight model/h9/ln_1/g with shape [1024]
# Loading TF weight model/h9/ln_2/b with shape [1024]
# Loading TF weight model/h9/ln_2/g with shape [1024]
# Loading TF weight model/h9/mlp/c_fc/b with shape [4096]
# Loading TF weight model/h9/mlp/c_fc/w with shape [1, 1024, 4096]
# Loading TF weight model/h9/mlp/c_proj/b with shape [1024]
# Loading TF weight model/h9/mlp/c_proj/w with shape [1, 4096, 1024]
# Loading TF weight model/ln_f/b with shape [1024]
# Loading TF weight model/ln_f/g with shape [1024]
# Loading TF weight model/wpe with shape [1024, 1024]
# Loading TF weight model/wte with shape [50257, 1024]
# Initialize PyTorch weight ['h0', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h0', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h0', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h0', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h0', 'ln_1', 'b']
# Initialize PyTorch weight ['h0', 'ln_1', 'g']
# Initialize PyTorch weight ['h0', 'ln_2', 'b']
# Initialize PyTorch weight ['h0', 'ln_2', 'g']
# Initialize PyTorch weight ['h0', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h0', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h0', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h0', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h1', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h1', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h1', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h1', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h1', 'ln_1', 'b']
# Initialize PyTorch weight ['h1', 'ln_1', 'g']
# Initialize PyTorch weight ['h1', 'ln_2', 'b']
# Initialize PyTorch weight ['h1', 'ln_2', 'g']
# Initialize PyTorch weight ['h1', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h1', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h1', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h1', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h10', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h10', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h10', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h10', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h10', 'ln_1', 'b']
# Initialize PyTorch weight ['h10', 'ln_1', 'g']
# Initialize PyTorch weight ['h10', 'ln_2', 'b']
# Initialize PyTorch weight ['h10', 'ln_2', 'g']
# Initialize PyTorch weight ['h10', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h10', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h10', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h10', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h11', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h11', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h11', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h11', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h11', 'ln_1', 'b']
# Initialize PyTorch weight ['h11', 'ln_1', 'g']
# Initialize PyTorch weight ['h11', 'ln_2', 'b']
# Initialize PyTorch weight ['h11', 'ln_2', 'g']
# Initialize PyTorch weight ['h11', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h11', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h11', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h11', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h12', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h12', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h12', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h12', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h12', 'ln_1', 'b']
# Initialize PyTorch weight ['h12', 'ln_1', 'g']
# Initialize PyTorch weight ['h12', 'ln_2', 'b']
# Initialize PyTorch weight ['h12', 'ln_2', 'g']
# Initialize PyTorch weight ['h12', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h12', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h12', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h12', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h13', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h13', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h13', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h13', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h13', 'ln_1', 'b']
# Initialize PyTorch weight ['h13', 'ln_1', 'g']
# Initialize PyTorch weight ['h13', 'ln_2', 'b']
# Initialize PyTorch weight ['h13', 'ln_2', 'g']
# Initialize PyTorch weight ['h13', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h13', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h13', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h13', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h14', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h14', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h14', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h14', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h14', 'ln_1', 'b']
# Initialize PyTorch weight ['h14', 'ln_1', 'g']
# Initialize PyTorch weight ['h14', 'ln_2', 'b']
# Initialize PyTorch weight ['h14', 'ln_2', 'g']
# Initialize PyTorch weight ['h14', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h14', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h14', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h14', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h15', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h15', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h15', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h15', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h15', 'ln_1', 'b']
# Initialize PyTorch weight ['h15', 'ln_1', 'g']
# Initialize PyTorch weight ['h15', 'ln_2', 'b']
# Initialize PyTorch weight ['h15', 'ln_2', 'g']
# Initialize PyTorch weight ['h15', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h15', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h15', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h15', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h16', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h16', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h16', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h16', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h16', 'ln_1', 'b']
# Initialize PyTorch weight ['h16', 'ln_1', 'g']
# Initialize PyTorch weight ['h16', 'ln_2', 'b']
# Initialize PyTorch weight ['h16', 'ln_2', 'g']
# Initialize PyTorch weight ['h16', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h16', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h16', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h16', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h17', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h17', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h17', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h17', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h17', 'ln_1', 'b']
# Initialize PyTorch weight ['h17', 'ln_1', 'g']
# Initialize PyTorch weight ['h17', 'ln_2', 'b']
# Initialize PyTorch weight ['h17', 'ln_2', 'g']
# Initialize PyTorch weight ['h17', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h17', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h17', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h17', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h18', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h18', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h18', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h18', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h18', 'ln_1', 'b']
# Initialize PyTorch weight ['h18', 'ln_1', 'g']
# Initialize PyTorch weight ['h18', 'ln_2', 'b']
# Initialize PyTorch weight ['h18', 'ln_2', 'g']
# Initialize PyTorch weight ['h18', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h18', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h18', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h18', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h19', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h19', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h19', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h19', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h19', 'ln_1', 'b']
# Initialize PyTorch weight ['h19', 'ln_1', 'g']
# Initialize PyTorch weight ['h19', 'ln_2', 'b']
# Initialize PyTorch weight ['h19', 'ln_2', 'g']
# Initialize PyTorch weight ['h19', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h19', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h19', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h19', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h2', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h2', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h2', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h2', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h2', 'ln_1', 'b']
# Initialize PyTorch weight ['h2', 'ln_1', 'g']
# Initialize PyTorch weight ['h2', 'ln_2', 'b']
# Initialize PyTorch weight ['h2', 'ln_2', 'g']
# Initialize PyTorch weight ['h2', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h2', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h2', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h2', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h20', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h20', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h20', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h20', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h20', 'ln_1', 'b']
# Initialize PyTorch weight ['h20', 'ln_1', 'g']
# Initialize PyTorch weight ['h20', 'ln_2', 'b']
# Initialize PyTorch weight ['h20', 'ln_2', 'g']
# Initialize PyTorch weight ['h20', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h20', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h20', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h20', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h21', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h21', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h21', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h21', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h21', 'ln_1', 'b']
# Initialize PyTorch weight ['h21', 'ln_1', 'g']
# Initialize PyTorch weight ['h21', 'ln_2', 'b']
# Initialize PyTorch weight ['h21', 'ln_2', 'g']
# Initialize PyTorch weight ['h21', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h21', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h21', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h21', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h22', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h22', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h22', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h22', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h22', 'ln_1', 'b']
# Initialize PyTorch weight ['h22', 'ln_1', 'g']
# Initialize PyTorch weight ['h22', 'ln_2', 'b']
# Initialize PyTorch weight ['h22', 'ln_2', 'g']
# Initialize PyTorch weight ['h22', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h22', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h22', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h22', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h23', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h23', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h23', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h23', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h23', 'ln_1', 'b']
# Initialize PyTorch weight ['h23', 'ln_1', 'g']
# Initialize PyTorch weight ['h23', 'ln_2', 'b']
# Initialize PyTorch weight ['h23', 'ln_2', 'g']
# Initialize PyTorch weight ['h23', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h23', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h23', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h23', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h3', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h3', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h3', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h3', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h3', 'ln_1', 'b']
# Initialize PyTorch weight ['h3', 'ln_1', 'g']
# Initialize PyTorch weight ['h3', 'ln_2', 'b']
# Initialize PyTorch weight ['h3', 'ln_2', 'g']
# Initialize PyTorch weight ['h3', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h3', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h3', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h3', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h4', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h4', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h4', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h4', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h4', 'ln_1', 'b']
# Initialize PyTorch weight ['h4', 'ln_1', 'g']
# Initialize PyTorch weight ['h4', 'ln_2', 'b']
# Initialize PyTorch weight ['h4', 'ln_2', 'g']
# Initialize PyTorch weight ['h4', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h4', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h4', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h4', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h5', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h5', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h5', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h5', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h5', 'ln_1', 'b']
# Initialize PyTorch weight ['h5', 'ln_1', 'g']
# Initialize PyTorch weight ['h5', 'ln_2', 'b']
# Initialize PyTorch weight ['h5', 'ln_2', 'g']
# Initialize PyTorch weight ['h5', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h5', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h5', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h5', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h6', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h6', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h6', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h6', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h6', 'ln_1', 'b']
# Initialize PyTorch weight ['h6', 'ln_1', 'g']
# Initialize PyTorch weight ['h6', 'ln_2', 'b']
# Initialize PyTorch weight ['h6', 'ln_2', 'g']
# Initialize PyTorch weight ['h6', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h6', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h6', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h6', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h7', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h7', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h7', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h7', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h7', 'ln_1', 'b']
# Initialize PyTorch weight ['h7', 'ln_1', 'g']
# Initialize PyTorch weight ['h7', 'ln_2', 'b']
# Initialize PyTorch weight ['h7', 'ln_2', 'g']
# Initialize PyTorch weight ['h7', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h7', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h7', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h7', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h8', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h8', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h8', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h8', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h8', 'ln_1', 'b']
# Initialize PyTorch weight ['h8', 'ln_1', 'g']
# Initialize PyTorch weight ['h8', 'ln_2', 'b']
# Initialize PyTorch weight ['h8', 'ln_2', 'g']
# Initialize PyTorch weight ['h8', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h8', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h8', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h8', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h9', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h9', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h9', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h9', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h9', 'ln_1', 'b']
# Initialize PyTorch weight ['h9', 'ln_1', 'g']
# Initialize PyTorch weight ['h9', 'ln_2', 'b']
# Initialize PyTorch weight ['h9', 'ln_2', 'g']
# Initialize PyTorch weight ['h9', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h9', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h9', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h9', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['ln_f', 'b']
# Initialize PyTorch weight ['ln_f', 'g']
# Initialize PyTorch weight ['wpe']
# Initialize PyTorch weight ['wte']
# Save PyTorch model to aitextgen/pytorch_model.bin
# INFO:aitextgen:Loading 355M GPT-2 model from /aitextgen.
# Save configuration file to aitextgen/config.json
# INFO:aitextgen:GPT2 loaded with 354M parameters.
# INFO:aitextgen:Gradient checkpointing enabled for model training.
# INFO:aitextgen:Using the default GPT-2 Tokenizer.

# %% [markdown]
# ### Fine-tuning

# %%
ai.train(file_name,
         line_by_line=True,
         from_cache=True,
         num_steps=5000,
         generate_every=1000,
         save_every=1000,
         save_gdrive=True,
         learning_rate=1e-3,
         batch_size=1, 
         )
# Out:
# INFO:aitextgen:Loading text from dataset_cache.tar.gz with generation length of 1024.
# INFO:aitextgen.TokenDataset:TokenDataset containing 19,287,928 subsets loaded via cache.
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:448: LightningDeprecationWarning: Setting `Trainer(gpus=-1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=-1)` instead.
#   f"Setting `Trainer(gpus={gpus!r})` is deprecated in v1.7 and will be removed"
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/configuration_validator.py:259: LightningDeprecationWarning: The `Callback.on_batch_end` hook was deprecated in v1.6 and will be removed in v1.8. Please use `Callback.on_train_batch_end` instead.
#   f"The `Callback.{hook}` hook was deprecated in v1.6 and"
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   0%|          | 0/5000 [00:00<?, ?it/s]
# 1,000 steps reached: saving model to /trained_model
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 1,000 steps reached: generating sample texts.
# ==========
# , but it also works, and the film has been a great, great film. The film is great. It has a lot of moments, and it's a great movie. It is a great film, but it does not follow the book. The acting is great, the story starts as a beautiful house with the main character. It is too long, as well as the film itself. It is the film. The plot is a little boring, the film is very predictable and very predictable, the story has some very funny moments, but the acting is very strange. The acting is very good, the writing is over-dramatise, the film has lots of moments where the film is shown in a musical hall and a musical hall. It's a good movie, but the direction is very bad. The film may not be a good movie, but it's still a very cheesy one. And you could't imagine what other is making. It's a good movie, and if you don't go to see it, you're not expecting to be disappointed."
#
# ==========
# 2,000 steps reached: saving model to /trained_model
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 2,000 steps reached: generating sample texts.
# ==========
#  to the cast. But the film is just a few hours of film."
#
# ==========
# 3,000 steps reached: saving model to /trained_model
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 3,000 steps reached: generating sample texts.
# ==========
#  I am just gonna just start this review on this site. I think this should be his first exposure to this movie. I mean it was so bad that I was scared of seeing it on DVD, and I did not understand it. I'm just too happy that this was made, and I don't understand what the movie has to offer. I mean. this is so bad that I was even disappointed in this movie. A movie is great and I think it should have been made. I'll go down as the main character has been getting on with his wife. I will always be interested in the movie, and I'm really glad to see this movie. It's a real movie, and I was the biggest person of all time. This movie is good, but I mean it's all that bad, I could not get on this movie when it finished. I cannot believe that many people would be angry about this movie, but I did not agree with them. If you like it, then I will certainly be able to go see this movie. The movie is very good, I am afraid. The acting and the dialogues are good, but this movie is not not the best."
#
# ==========
# 4,000 steps reached: saving model to /trained_model
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 4,000 steps reached: generating sample texts.
# ==========
# , it is a very bad movie, but the acting was very good. I enjoyed the action, the plot, and the plot. The only thing I wish was the best way I could describe it was that it was really bad, but not that bad. Some of the dialog did show the characters, but the actors didn't show the outcome. I had to say I was disappointed, the movie is so predictable that I was asking the question 'Is it really about the plot? A simple question I can say I am just telling you. There were a few episodes in it, but that's about it. It just is the plot, I had problems with the plot, and the plot was just dull. The fact that I could watch this with my friends was not a mystery, but it was just the plot, and the acting. I'm not sure if it was ever made, but it was just plain boring, I could watch it without the characters. The storyline was pretty thin, and nothing a real mystery was resolved. I was thinking about it, and the storyline was more complicated than the plot. In some moments the dialog was just there for a very short time. Other times I think the actors tried to make a really good movie, and the ending
# ==========
# 5,000 steps reached: saving model to /trained_model
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 5,000 steps reached: generating sample texts.
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=5000` reached.
# ==========
#  was not really too sure what to do with the titular character. It was so much more like a big disappointment. It was in the sense that it would be the worst movie we've ever seen in a while. How can you get an answer to what you have already just just watched? If you're going to spend time with this movie, you might have a better time with this movie. I'm glad I did. I can't blame the acting. I thought the actors who gave an excellent job did not make a good job. They did not make a perfect job for the movie. I'm sure they could have given the movie a 7.0. I'm sure there were a few people who had no idea what to do with the character. I don't know what to do with their actions. The movie just didn't work. I can relate to them. They seemed to tell the story that they could have done it too well. I don't know what to do with those two. I'm sure if they were just trying to make a movie about what would happen with the other characters. Then they built a lot of suspense. I'll just assume they were trying to make an overrated movie. I hope they did. But the movie was
# ==========
# INFO:aitextgen:Saving trained model pytorch_model.bin to /trained_model

# %% [markdown]
# ## Inference

# %% [markdown]
# ### Re-load model for increased performance while inferencing

# %%
ai = aitextgen(model_folder="trained_model", to_gpu=True)
# Out:
# INFO:aitextgen:Loading model from provided weights and config in /trained_model.
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:370: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# INFO:aitextgen:GPT2 loaded with 354M parameters.
# INFO:aitextgen:Using the default GPT-2 Tokenizer.

# %% [markdown]
# ### Inference for each rating

# %%
reviews = []
for i in range(1,11):
  reviews.append(ai.generate(n=5,
                             prompt=f"{i}<|rating|>",
                             prepend_bos=None,
                             min_length=None,
                             max_length=500,
                             temperature=0.8,
                             top_k=40, # Limits sampled tokens to the top k values
                             #top_p=40, # Limits sampled tokens to the cumulative probability
                             #num_beams=5, # If greater than 1, executes beam search for cleaner text
                             #repetition_penalty=1.0, # If greater than 1.0, penalizes repetition in a text to avoid infinite loops
                             #length_penalty=1.0, # If greater than 1.0, penalizes text proportional to the length
                             do_sample=True,
                             return_as_list=True,
                             ))

for i, rating in enumerate(reviews):
  rating_text = "-"*15 + f"\n  Rating: {i+1}\n" + "-"*15
  print(rating_text)
  for j, review in enumerate(rating):
    print("'" + review.split("<|rating|>")[-1] + "'")
  print()
# Out:
# ---------------
#   Rating: 1
# ---------------
# 'I do not really believe that this film was ever seen on video. It was simply an insult to the intelligence of the main characters.If I had a problem with this movie I would have no problem with the film. The story and atmosphere of the film had absolutely nothing to do with the movie. I was glad to see what I could do with the film. I was laughing at the movie, and I did not have the same feeling as the film. And it's pretty clear that it was a very poorly executed setup. Don't blame the actors for this movie. They should be ashamed to be ashamed for the poor acting. The music was very badly written and the sound was horrible. I can only think about how much better it was. The film is a lot of the film. I didn't know what to do with the plot. It seemed to be a nod to films like the 'Killer and the Bird' and the 'Killer. I cannot deny this. I have no idea what director/actor/actor/FX was thinking about. I can't believe what people were thinking when they tried to emulate a film. I had no idea what to do with the film. I don't blame them for it. I have no idea. They would have made a good movie. If I had given a single thing to this movie it would have been good. I would have given it a zero."
# '
# 'The movie could have a more thrilling ending. There was no suspense whatsoever, there were no suspense whatsoever. The pace of the film was boring and unnecessary to the story while simultaneously being a complete idiot."
# '
# 'This movie was horrible, for the most part. The story is like a comedy, and the acting is a bore. The acting was terrible, the cinematography was terrible, the direction was terrible, and it was all wrong! One thing I had not enjoyed was that the actors' acting was so bad that they could have gone at a better job with the actors. There were a few good performances and I would like to go see a sequel, but I didn't like the movie at all. Please don't give this movie a watch. I must have thought I could watch it instead. The acting was terrible, the writing wasn't good, the editing could've been better, and the visuals was just good, the editing was terrible, and the special effects looked stunning! I'd rather have the computer game, if I was a computer game. I will be at least surprised. I will never see the video game. At least I can go see this movie, and I don't know even know if I can watch it. I will say that. I didn't. After five minutes, I thought it was the movie's ending and I thought the ending. I was right! I have never enjoyed the game, and I've never been a fan of any game too. I don't know what they are trying to do. If I have any problem with movies that are meant to make you feel like a game, I can't blame any of them. I gave it a 3. It was terrible. The game was not that bad. I had to wait for it. I was wrong! I do not know what one of the ""bad"" (that is a spoiler ahead) characters was. I don't know why it would've been better. I just don't know what else can do. I don't know what they were doing. This movie had just so bad. It sounded like a game game. I hope I saw this game. I don't blame it. I didn't believe the game's not that good. It was just a game. The game itself was terrible and they made me want to see. The game wasn't worth a viewing or a price of $10,000,000. I'm sorry but I guess the game was a game. I hope that I will never see this game. It just seemed too rushed. Even the play itself seemed forced. I am just tired of the game and I'
# 'I'm a fan of the movie, I didn't like it. It was just an excuse for the plot. It wasn't even funny. If you are going to want to watch a movie about things, the story was so far fetched. The movie was a complete disappointment. It was only once, so no expectation could be fulfilled. I just wanted to love it. I wish they just couldn't have tried to show me that this could be so much better than the original, but they did. And if they had left out more, and relied less on on the script to make a movie, they should have left out their way. It was so predictable. How many times have this. The acting was terrible. The story was horrible. I will not go into spoilers ahead. I don't know what to expect to see from this movie. It was just too long. The storyline was predictable. There is nothing really good about this movie than that. I don't want to see this movie."
# '
# 'This is one of the worst movies I have ever seen in my life. I've seen a lot of movies, but I guess this movie was too much for me. The characters are the same, and if you are an avid person then you might be more than willing to watch them. I'm glad I did. I would have liked to give this movie a watch or a watch. It is a shame that they tried to make a movie. But if I had never paid to see this it, I would have probably paid the money to make it. I will no for it and I would have been more involved in the plot. The acting is horrible. The cinematography was terrible. I couldn't stop thinking that the actors would have been able to make such a movie. I am sure there were one or two of them. The plot line doesn't work. The script is atrocious. The actors are terrible and the story is absurd, the actors who are supposed to be actors? I don't know if my opinion is high or high! The actors who are on the movie. They do not seem to have any sense of realism on the screen. The story is weak. I don't care about the main character. I don't know who the hell was with them. I don't know who the hell is. I don't know who the hell was. The movie tries to tell about how it should be. It doesn't. There is nothing new. What I know is about is that the movie is just a copy of the film from the beginning. The ending is horrible. The ending is disappointing. The movie seems tired at best. I was warned this would have got better. It's just a movie that will be interesting to watch. Avoid at all costs. Avoid at all costs."
# '
#
# ---------------
#   Rating: 2
# ---------------
# 'I didn't like the film, but it actually got worse when it started. And I thought it would be a good film but unfortunately I didn't see any good acting or a bad script."
# '
# 'I am a big fan of the series as well as my favorite of the series. And the series is great. I found this to be a very entertaining series which was the biggest disappointment in the series. I had to read the book and the book I thought was very disappointing, but I thought what I did know about this show is that it is the best of the series. And what I like is what I say and what is the problem with the new characters. I find that all of them, especially the main characters and their stories, are completely unappealing, even for the most part. We don't get to see them even have any sort of resolution, and they don't even even know how to explain. But the only suspense in this show is the one of the characters that did all of them justice. I could go right with it, but the truth is that the story is just so predictable and there isn't any suspense or excitement even suspense or excitement at all. The movie was just a complete disappointment. The characters who were in it were so shallow they couldn't have much impact, and nothing else did that. The fact that the two main characters are so shallow and uninteresting that it doesn't mean that they were any less or less believable than the real characters. All they needed was so badly acted. I can't blame them, because the acting was awful and horrible. The only highlight I could think of was the ending. I don't know what other people were thinking. The only reason I gave it a 2.5 is because I've got to like and found out exactly what they were thinking. The only reason I didn't care about the series. The movie I could go a movie, but you could be wrong. I don't know how to make a movie about this universe. They should have left this movie like ""Don't waste your time on this."" I did not like the series until I saw the movie. At least once the movie started. I just couldn't get it until I realized that the series was a good movie. I had nothing to do with the series. I just did not want to see it. I thought of the series. I thought that the episode was going to have an ending. I really don't know what to say. What I didn't like was the fact that it wasn't as great as the movie. I don't understand. I don't know anything about'
# 'There is one thing I loved about this movie, the movie itself is good enough. The movie itself is an excuse for a great movie. The acting is good, the music is good, the plot is good. However, it is not really a comedy. I don't really feel bored during the film, which is very obvious. I also am not a fan of the previous two of them as I am a fan of his characters. I found all of them to be too much of a distraction. They were too little that little to detract from the film itself. Maybe that was the case in the story of the film. The ending, the conclusion, the ending, the ending, the ending. One good thing I would've liked was the last one. But as I said, the movie didn't have a good plot, nothing really happened. Just so nothing really. I don't mind seeing all the movies in the series. This is a disappointment. The only thing that could have been good to the original, or at least entertaining. It was too predictable, too predictable, and too predictable to be that good. Just don't waste your time. I mean, if they have a chance to make another great films, they can, they are so bad they are just too bad they can be good. I'll say it has a good plot. First of all, there are so much as you expect in the movie that this movie is nothing more than a showcase for what happens to you. The jokes are lame and just as it has just been, it's just too predictable. The storyline is just plain stupid. I can't fault the movie, it's just too rushed and too predictable. You just don't have enough evidence of what's going on. The characters' names are so lame that they aren't even funny. Also, the editing. I didn't even know what to expect. I know what to expect when watching it. How many people watched it? I was waiting for it to finally end. I don't know how I can explain what I thought a good movie was for a movie. I can't blame a movie on the movie, but I do feel bored. I don't know what you can do and that's all you can do. The movie itself is a problem, as all I know about this movie, it's just too long. It is a very bad movie."
# '
# 'This movie is an insult to what I had heard was a poorly acted and badly written script. The plot is convoluted and predictable at best. The acting is appalling and the special effects (which are not a good sign) were appalling. The only thing to make it a watchable film is the scene when the two meet are dancing. At times, the story is about a person who is obsessed with his own life. It's an insult to the intelligence of a person who is slowly becoming a hero. I mean, I wouldn't recommend this movie. I mean, what a movie you're thinking. This film is like a movie about a man who is a God. I can't blame the movie. If you want to see a light-skinned-nonsense movie (or you'll get this wrong). I can blame the movie's poor message. It's one thing that one reviewer mentioned in the comments: ""If I can watch this movie for a few hours I can just watch it."" Then, that's the movie. I can't fault the acting. I don't want to blame the actors for acting. The movie's bad. I don't have much better to say. I like it. I don't want to blame the production. The cast is atrocious. I didn't really care about the plot. I don't know what else. I don't know what to say. It's just another bad movie. I don't know what to do with a plot. The editing was atrocious. The pacing was atrocious. The characters seemed forced and rushed. The direction was bad. I gave it 3/10."
# '
# 'I am an astronaut who is in a little space. He is forced by his ship. The ship is called 'Farscape' and is also a spaceship captain. I don't mind the captain. He is shown to be the captain. What a good thing! The captain's ship captain is not only the captain (which I suppose is not mentioned) but the captain turns into a hero. The captain's ship captain gets to know what he is doing. The captain is a baddie and he sends the captain aboard. If he is there he is a villain. I am willing to call him. He is a man. He was also called Captain. He must have been in real life. His captain is the captain. The captain also does not know what to do with the captain's plan. He is not the captain. He is not. He is a hero. I can only describe a hero. I loved the captain. His motivation. I want to know what they are doing is not a good enough explanation for the captain. Just a little bit off the charts. However, it is still a very nice, entertaining movie. I am sure I will watch it again. I am surprised that ""Ewing With Space"" did not have it's problems. I cannot say I just have a problem with this movie. It just felt like it had no plot. The first hour or so were boring. The second half of the movie seemed more like a TV series. (I hope that would be the reason to watch it. I was on an island) the rest of the movie was predictable.I don't know what others would have thought of either of that. It is the first half of the movie that saved this movie. But when it started it became a complete, predictable movie. I was expecting to be a good movie. However, what the hell was the effect. I was left wanting to see the movie as if I could have never seen it. I didn't think I would. I thought it had a good plot. As far as I know what to do with the movie. I am glad that I did not get to see it. The first half of the movie did not seem to really make it a good movie. I would have thought that I would have liked to see more of it. ""Ewing With Space"" is a great movie. It seems that the writer/director should have left the director's'
#
# ---------------
#   Rating: 3
# ---------------
# 'This is one of the worst movies I've ever seen in the movie. The only reason it is entertaining is because of the great acting. I must have said it had something to do with it for me. It is all like it was for the first time. I don't know what so ever, what was the reason the movie would have stayed with me with me. I will talk about all things about the movie, but I was really looking forward to the characters. I didn't know what to do with this movie, it just didn't have any good or anything else to do with the story. I just sat down and wondering if anyone else could have done much better and if I will say something for it, there would be someone who could have done better and not lose my respect for this movie and just have what I thought was what the whole movie was about, the only thing I loved was the ending, in my opinion. I could have played the ending as if I had just paid a $3.99.00 to see a bad movie."
# '
# 'The best thing about this movie is that I have an idea of who the hell was. I am not sure the movie could have gone better. But the movie was so much more entertaining. One of the most entertaining movies I've seen in a while, and I have the best time at a time."
# '
# 'I am not going to be an expert, or anyone's case. I was really looking for this movie. Well, a little bit of an excuse, that would be expected for a film. The movie set up the premise of the first two movies, to tell the story of a man who slowly descends into madness. I am not sure why the first two movies are just as important as the film. The first two were completely different. The second one had a much more serious plot. The second one was more action at the same time. The movie was just a complete waste of the first two. The second one had a little more suspense, although I thought the characters were more to tell in an more entertaining, entertaining way. The second is more the same. The beginning is just a copy of the TV series from the first two. The final two were more of the same time. The characters were more the same age as the first two. I'm not sure what they were trying to achieve. I found this to be more of a total waste of space. I don't know what other people have left with. I thought the action was just too much. I don't know what we've seen. The action was too much. I'm not sure if the acting was just a setup or an excuse to see a horror game. For an action game, it wouldn't even have been so believable. It's like the ""The Sixth Sense"". I was so bored with this I must have thought of it as another action game. It's almost a waste of time. The story line was so very predictable (not even really a good reason at least to me) that it was so predictable. The storyline looked so choppy and unnatural. There was no suspense whatsoever, it just wasn't. I was never sure about what else to expect and that is why I kept watching it. First off, the first two seasons were very boring. I don't know what people were thinking. But the second was good enough to make this film one of the best that I've ever seen, because the acting was just too convincing. But the second third one (so far they could have used a more than three more minutes of suspense for the story.) was actually better than the first two. I gave it 2 stars and I was glad that I had been like this ever since I was. I didn't give it a 1."
# '
# 'Some people will want to see this movie and I am not sure what it is even attempting to be. I was disappointed with this movie. The only thing I can say is that the ""action"" is the first time you get to see this movie. I do not know what to do with it, but I have no problem with the movie. I can not resist watching it. This was like watching pornoitation movie. As an avid fan of the genre I was questioning the film's quality and its message. The story really seemed forced and forced. I mean I could have done something better but to make something better. I could have been more honest, then. I don't know what to do with these movies. It was like a movie about two people and I was wondering why you would have a good time with it. It is a good idea for a good movie and this movie was a good movie, but that was too much. I did not get it. I kept waiting and waited until the end credits rolled. What a movie. I was thinking this was going to be a great movie and to finally get to know. And for the reason. I have a doubt about that. I will have to say I have nothing against the movie. I did not like it, I think it's just a movie. It was an awful movie. I was trying to be a good movie as well as a good movie. But the movie went from bad looking to bad. I found it quite disappointing. Some people were surprised with the movie. I have to say it was bad."
# '
# 'Having a huge craving for watching this movie i was very disappointed. First off the acting i did like the ending of a relationship which i was very pleased by. I am still trying to avoid this movie. I'm wondering if it would have been able to use a good screenplay as such as it was. If you have not turned off the movie by the time i watched it i was confused when i was making this movie. I had to wait for this movie. I gave it 4/10 because when i was finished the movie i didn't want to see it again."
# '
#
# ---------------
#   Rating: 4
# ---------------
# 'I really wish this movie had a somewhat decent flow. And the acting is atrocious and the rest is mediocre; the dialog is dull and the direction is bad, well, okay. You don't get to see a bad movie."
# '
# 'It's clear from the start that a lot of the film was originally intended as a re-imagining of a short film. I found it quite frustrating to watch, as there were no surprises. I was hoping the first half of the film would have seemed less of a good idea, as if it was supposed to be a musical. The first half is too much for me, and the ending, but the final half the film was too much for me. I could have saved the film for the ending, but it's over. I didn't know what to do with the movie. I didn't care for the story, I just thought it would have an ending. I have no problem with the ending. What I'm trying to say is that, is that there is nothing for it. I didn't care about the character-defirming, and seemed to be left uninspired. I didn't care about the ending, the ending, the rest of the characters, the story was just too predictable. I did like that they had a little more to do with the story. The first 15 minutes of the film, while having a good moment with the characters they had the most powerful moment. However, I can't blame the original plot, as it does have a great cast, including a good couple moments that I could have had less than a little more time to watch. The story itself was completely predictable. I did however feel like they could have added some originality in the storyline. I had to avoid the cheesy cliches in the trailer. I don't know what they could've done with it. It seemed to have something to do with the story. I have a doubt I will go in the MCU, if I didn't like the way they did with the new Spider-Man.But I could have had more respect for this character. I'm glad I did. They didn't have Spider-Man. They did it. They did it with too much focus on the Spider-Man. I thought they had a little more time and money to go with it. Maybe I don't care what happened with that. I just don't care what happened to her. They just don't care what the characters actually were doing. I know I'm talking about the characters. I don't know who is the villain. This is the problem of the movie. I don't even know what the hell the title is.'
# 'I don't like the movies where you want to be at a club or a club when you want to. If the film are supposed to have a good mood then it could have taken place just a bit more than you know. The performances are atrocious and the screenplay was horrible, it could have shown something if they didn't have enough money to make a poor movie than the rest of the film which was more of a distraction than a little action flick. It was a total disappointment. I'm not a fan of the genre for film like this one however but I am glad there wasn't enough to make a decent movie. I don't really like films that were basically not worth it like I was with the time and money, however I have seen it so much better and more of it. But, as soon as I watched this movie, I sat to watch it. However, I was right, I was right. I didn't want to see it. I had my hopes for this movie to be the worst movie i have ever seen. I'm disappointed. They had potential. I was wrong. I think the plot was more, it was obvious that there was not enough to make it a coherent story. But, I don't know what the hell was going on with the storyline. I do not know what any other person could expect. But, I'm sure they didn't get a good deal of screen time. We don't really have a lot of the time to waste in your time. I can't blame that on you. It's a shame they didn't have more money. And, I think I was wrong. I'm not like to be forced to watch a movie. I don't know what kind of movies. But I thought they were pretty. Or maybe I really should have the money to pay for it. I thought it was a good movie. I'm trying to figure out just how. It wasn't that good, I didn't have a good time, I thought it would be okay. I just didn't appreciate the character development. I felt like the movie would've been better. It was as if nothing else had done it before. And, and the plot itself was a cliché. I don't know what to do with the movie. It was rather slow paced. I thought it might've been good and the cinematography was good but the other characters didn't have much impact. The story itself'
# 'The first half hour and a half-hr of this film is a rather boring one. There is a good enough amount of energy and the two half-hour duration of the film is wasted in the climax. It is very reminiscent of the previous two, but the first half hour is wasted in the second half. The second half hour is wasted in the third half. It was so long and some of the time spent on the rest of the movie. The first half of the film is good, and the second half of the film is very tedious. The first half hour was wasted on an unnecessarily long, unnecessarily long, predictable ending. I have no idea what this movie was trying to say. The second half of the film seemed forced with too much of a story. There was nothing positive about this movie that could make you go ""why? You don't get too much development"" to the story. The ending to the story that was supposed to bring a story to an ending would have had potential with an original story. The ending to the end of that it was not as good as the last two. But it was still a waste of time. In a lot of the films, I'm sure they should have done that right. I don't know what the hell was the deal with the ending to the story. The climax scene was a tad confusing, but nothing likeable as the first two. I didn't get this one. I can only say that the movie would have been better. And if this movie had been good, then I would have given it a 7/10."
# '
# 'I was looking forward to see this because the trailer was good at just about every minute. I was waiting for an hour. I'm sure I am right. This is a film that was nothing but an excuse to make the film look like it is a film. I'm sure that this is not a film I was sure, and I was hoping for a laugh. I kept thinking that it was a good film but the characters were not believable. I don't mean that this movie is a film. The characters were not so believable and the story itself. The main problem is the ending. I don't mind it and it looks like it was a ""action"" movie. I don't want to see much of the story. I don't want to see anything like this but I found it to be an disappointing movie, and I didn't like the ending. I'm sure that a lot of people will not like and want to do about the character. I hope that in another film they will have a decent chance to see an ""great film"", if you think about it. I would recommend this movie"
# '
#
# ---------------
#   Rating: 5
# ---------------
# 'This movie seems to only be meant to be a film about a super jet jet. I don't know what it is about, and I don't know what to do with the concept. I'll be not sure a single person will get offed by the film, but it is a movie about it. That is a testament to the first film in the series, and the last one is great. It is the first of these I know that this movie was so much better than any other of the TV shows, which is what I really liked about this movie. They were so much more entertaining watching the first movie. However, it took a while to watch the first two, after they had begun a little longer, a little more suspense. I do not know what I mean, since they've already been doing this, they made a very good movie, and they were nice to watch the first two when we were watching the first. I like the first two. However, the second time I checked out the new series, I was pleased. I loved it. I wish they had had made the series. I thought it would have been a great, fun and entertaining series. I was glad to see it again in the meantime. I'm glad that you didn't get too attached to the first two. I have to say, my friends (in love) have been thinking about the series to stop what they did. I was surprised that it didn't get very interesting until I saw it. I thought it was just over. I'm sorry - I couldn't bear to say more so. I know that I should have stayed with them when I watch a ""mystery"" episode. I won't give it away, but I'm sure that I could enjoy it. I gave it 9/10, but I hope they didn't have to go back for the original series. I'm sure this isn't what I am thinking about. I had a problem with this movie. I was hoping I couldn't stop thinking about anything. I thought it would be a very interesting episode and to watch it. I was sure that the first two would be better, but after watching this movie, I did not like seeing the first two. There is nothing that could've so much potential going with it. It would have been better if he had made a good episode. I don't even know who the hell was. I didn't feel bored or'
# 'I don't know what any other reviewers will make the movie. This time they are at a certain time they are not sure what to do with the movie. I was sure they were trying to make a movie that would make no sense. It's the movie that was supposed to be scary, but there are a few scenes that I don't see coming from a movie. I really don't know where this was going with all the high school high school. I was not sure what to do with the ""real"" of the story and don't even know who the hell was. I don't think I can fault the movie. I know the cast was awful but the movie is supposed to be good and if you are ever bored then you probably can't watch the movie. I didn't know what to do with the ""real' of the movie. I didn't care about what any of the characters went and where they are. I am sure that the movie was supposed to be a masterpiece or something or something like that. I was glad, however, that the movie wasn't for me. I don't really know what to do with the movie."
# '
# 'This is a film that makes no sense. I don't know what the hell did I know? This is a film that seems to have nothing plot or plot. In fact, I don't know who the characters are; the characters that are in the movie are just a mere distraction. I don't know what to blame. I'm sure they were trying to be ""different"". They don't really work together. They don't really have any charisma or charisma either. They only work on paper. They just don't seem to have any charisma or intelligence or even make any sense. They don't want their actions and actions. They just go to see themselves. They don't seem to be in the film. Not even enough suspense or suspense. In fact, they just don't work together. They all talk and feel like they are going to have a good time to be a hero. But I doubt they should have left out more of this for a little more. I'm glad they did. I can't blame them for what they did. They just don't do any of them. Even in a scene in which they are just standing there, they have a problem. This is a problem, the performances are the only good thing about this movie. For example, I didn't care what they were doing. I didn't care about any of the characters in the movie. Someone else's acting was pretty much convincing. I didn't care for them. I thought they had a little more than 5 minutes. I'm sure they should have cut this one and they did a good job. As it could have been a good movie, it was OK. But the problem is with it. It was bad. It was just plain awful. The effects were pretty fine. However, I didn't like the ending. It seemed to go from there. I kept wondering ""really was no plot or anything in the book."" I had no idea what to do with the character. I did not mind that the ending was going to be that bad. We should know it was going to take place. I did not. I can't fault it for the actors who were given ""A"" for the acting by the main characters. They just said their lines, ""You didn't notice this,"" I just didn't care about the characters in any way whatsoever. There wasn't much to do with the end. I don't know what they'
# 'Some people are so tired of me this movie, but I'll do a movie. The premise is simple and it is an amazing piece of work. The acting is atrocious (as we are supposed to find) but the directing is so awful. There are so many bad scenes that you can barely watch. I didn't want to see this movie. I just want to see a movie for the money to see a great movie. I don't give it 10 stars (I'm not going to give it a 1 but i am going to give a 2 because i wish they did a better movie). It's too bad. I did not want to be a ""bad guy"". I didn't care about the characters and the storyline. I didn't care about them. I don't think I would want to watch a movie with a bad guy and a bad guy. I'm not a fan of their, or even I'm not. I don't really remember them. I don't know who else I wanted to see, the only thing I didn't do was that they should have shown them. I don't know why they did it. I don't like about them. I don't know what they were trying to do. I don't like them. They don't give the same sense of excitement as they did. They just kept doing too much, too. I don't know who you are. They don't care about either. I don't know what the hell was going on. I don't know if they didn't want to be the lead character in this movie. I don't think I don't mind the main characters who aren't. I don't really like the actors who were at all believable. The movie made me look like they were having a great time. I don't know what people really think of them. I don't really know what they were doing. I don't care about them, I don't think it was believable enough to be the only person that makes it better. It wasn't that bad. I don't know about them, they just don't know what to do with their movie. They looked like they were trying to show their own lives on screen. I do nothing for the characters, they seemed forced. I am just glad that the movie wasn't good enough to make a film. I can't blame the actors for their parts.I wish they had more lines. They'
# 'This is a film that really only captures the feeling of watching a documentary. It makes you question your sanity and your thoughts when viewing this film. My only problem is that it was going to be a great film. The only thing that really works for me is the fact that the movie could have been less about the real life of people. There was an overwhelming sense of urgency that was needed in the movie. It was interesting to see the real life of people that had a great time in life. I just can't wait for this film. Just don't let it pass. My vote is 5."
# '
#
# ---------------
#   Rating: 6
# ---------------
# 'Since the opening credits, I didn't get bored, and then watched it, and still enjoy watching it. It's a good movie, a movie, a bad film."
# '
# 'If I had never been better, I wouldn't have seen this. I didn't like the movie. I didn't like the acting or the directing. I feel like I was watching a TV adaption of the movie. But if you are not familiar with the previous two, then you should have not seen it. I don't like the ending. I don't know if they should have focused on the previous two. At least we should have waited about it for 20 minutes. If I didn't watch it, then it would have been a much better chance to have a chance to see a movie. I don't. I thought the cast and crew wasted a good chance."
# '
# 'This was the worst movie I've ever watched and I'm not sure who it was trying to be even a crime movie. It really was not clear who it was trying to be. Just like every other movie, it's not a good movie. But I am not sure what was wrong with the movie. It is the worst movie I have ever seen. It might have been better if a half hour was spent on the movie to make it at least give you a good example of what bad movie is, and not only that, it should have been a long lost effort to make up your sanity. It was just too much. Just a waste of time."
# '
# 'This is an interesting film for anyone interested in watching the ""bad"" and ""bad"" - the bad. The acting is wooden and the costumes were uninspired.I can't fault this film for the performances. The plot was just a little too rushed to the point the characters weren't convincing at all. The effects were too good. I will admit this is a fairly enjoyable movie to watch. On the other hand, the cinematographer was obviously meant to be effective during the course of the movie, but to be honest I don't think there a single interesting scene was as good as others. The music.which was never heard in this film. As it was used to, this movie didn't fit into the movie. It was very reminiscent of the movie 'Saw' at all. There were too many problems, I will just say that there was a few inconsistencies. I must have thought.how did the filmmakers let you know what to do? the plot line. The rest. The storyline was not as good as the previous two. I can only assume that the characters that they were playing are the same. I did it a little bit, and, to be honest, I didn't know what to expect. I mean that if they were trying to be a character that was supposed to be a character that was meant to be a hero and not a hero, they could not have made it. If they tried with the same story as the previous two, it would have been better going for them. The effects was awful, the actors were terrible, the effects were awful, the special effects. I thought I could take a better screenplay to make. But I did not.I thought that I should have tried to see more of the same kind of dialogue, as they did. I was left with only one bit of bad dialogue. There was a lot of noise which was supposed to be the result, and that was really the only thing to stay with. This movie was just bad. I could watch it. And why the hell of a doubt was that. And it was. No suspense. Just stupid. Just stupid. Very disappointing. If you don't like you are a superhero and you are a superhero then you should be a super hero or super hero you will enjoy this movie. I'm not a fan of superhero movies as I don't like superhero movies. But I was not the hero. It wasn't that it'
# 'The acting in the film were so wooden that it sounded like a computer game had been made by a team in the woods where they were in the woods. The film had nothing to do with a single performance, but the editing and the editing (which would have been more enjoyable to see if they were actually a computer game then this would have worked much better, and they should have had enough to do so much more with the movie). The only thing I can say is that the movie did not work for me was the computer game play.I would have liked to have had this movie on the front cover, but that was not enough to put you into the game but I can't fault for the graphics. If you want to watch an extremely stupid game then go for it then rent something else.If I had waited more, one could have played it. If not, I might have given this movie a 7.4 rating. I have a lot to go with. I mean, I must have had something more to do with the game, but the game did not have any consequence when I was picked up in the game. I mean, I'm not a big fan of the game, but if you want to watch anything I can be so. And there was no action. There were so many times that I didn't have to pay to watch. I mean, I didn't have that. The game was stupid and the game was horrible. I wanted to see some game. I'm not going to be too harsh on the game. I don't think it was the game the game was about to die. I'm not sure what happened to the game. I thought the game was pretty bad."
# '
#
# ---------------
#   Rating: 7
# ---------------
# 'This movie was amazing. I just wish I had had more time to spend the time with this film because of the great performances I will ever experience again. I was surprised to see this movie. The story is not as exciting as the previous movies this may have had. It is basically a bit more than the previous movie and the ending is a little more of an ending. I have no problem with the movie but the movie itself is more of a joke than the previous. I didn't see it in a theaters. I am sure what the hell was with that. I would have thought it was more exciting than the previous one. I don't mind it's a great movie, but I'm afraid it would have been better. It's a little too much over the top and too much of a spoiler but for a movie. I was not able to stay through the whole movie until I saw the previews. I have never had much interest in the story yet. I was left with a bad feeling in the film. It was so very slow it seemed too rushed. I thought this movie was really a little too long. There was little excitement and the movie had a very little too few good acting. I thought the plot was too fleshed out and too much. I was left with a big expectation. I'm sure it was going to be a copy of what I thought was so well done. I had a little disappointed. I also did not like the last two movies. I don't like the movie that much as I know I'm sure it was going. I know they should have have left the ending but the ending was so forced and rushed. Maybe she should have kept a secret to the end of that story. There is no reason this movie would have been made."
# '
# 'I just went to the cinema and didn't appreciate the story. I have the two problems, I have the problem with the time I saw the movie and even then the plot itself was quite impressive! The only problem is they didn't seem to work together so much on that we were left with the characters. The only problem is the ending. I don't know who the hell was. I know the story was the same as its predecessors. The ending was disappointing. The ending was a bit rushed and at times confusing. But it still made this movie a good movie in my book. I would enjoy the film. I also noticed the ending of the movie was not good. I can't blame the ending for this but they should be.I kept waiting for the rest to happen. The movie was good, and I thought."
# '
# 'This film is not as good as it is. I was expecting a movie. I thought I was watching the movie. I think I was at a good time and I thought it wasn't for me. I also think some of the main characters are somewhat shallow. I don't usually hate characters but they make sense. They have a lot of chemistry. I don't know what else to say about the film. I thought it wasn't a good one at all the same time. I was waiting for this to get out there (and I'm sure this is the case) but I do think it should be a great film. I couldn't fault anything else for the actors. I was bored and there's no doubt I would give it 10 stars because it is a huge disappointment.It was an unfortunate scene and when it came to the cinematography. I don't think there's even anything else to say about the film. I thought it was a poorly written film. I don't know what that was supposed to say. The film itself does an excellent job of creating an atmosphere. I was trying to give it 10 stars because I have the feeling that people are on the edge of their seats. But at least I thought it was one of the most interesting scenes in the film. I do think I was able to give it 7 stars because I thought that it was an awful film. The storyline was just atrocious. The film had a relatively thin build. It was so predictable. I was able to ignore the ending. It was not as good as the trailers it was. I did not like the ending. The ending, or anything else. I was looking forward to the end. I also felt like my mates who gave it a shot. I'm sure that I can fault this film. I've worked out this time they did it again. I don't know what a big disappointment, I do not know a very good one but it could have been enough. The movie was way too long I didn't like that, but this is a very good film."
# '
# 'I didn't think much of the comedy and the drama of the film. The scenes were just too much for me - especially when they were on a spaceship, they were getting caught up in a spaceship.It seems they are forced to fight off all the crew members from Star Wars. They would have been better off watching this film than watching the other Star Wars films from Star Wars. There were no need to be like this. I think that was too much for any film. I don't mind movies, but I am not a fan of Star Wars. I'm glad I did. The film doesn't have that great power as such, it is too much for me because we don't have a lot to do with anything. It's too much for me, it is too much of a problem. I won't waste a single moment with this film. As a fan of Star Wars, I would have thought this was a good film. I am sure this may have a lot to go with it. My only problem is that some of the effects don't work. I don't understand why they would have to have had to cut to lower some of them. The story is too much for me. It seems that the crew didn't seem to stop at once, especially when they got to see Star Wars. This is the only good thing, and I suppose the people who worked on this were given to the crew. This is the only thing I can say about it. I will give it a 6.0. I thought I had a bit more time and effort to watch it. I will give it an 8. I was not sure what to really understand. I thought the acting wasn't bad but it was entertaining. The cinematography was amazing, the directing is good, and the music was good. I thought the story wasn't quite as good as I thought it would have been. I am glad I did. I was getting into this film. I thought I should give this film 8.5."
# '
# 'I've heard this was an absolute hell of a story, but it is totally forgettable. It's not an Oscar-standard film, it is a pleasure to watch. But the movie itself is an action film."
# '
#
# ---------------
#   Rating: 8
# ---------------
# 'What is wrong with the book, is that they are just right. The characters are just stupid. They are only in the movie once in a while. The story is just random. It is just so over. The movie is too long, and it is too long. I don't know what that was because of the amount of time it was filmed.The plot is too short. It is too long. The movie could have been better, the acting is terrible. The story is too predictable. It is too confusing. The characters. I do not know what they were thinking. The plot line was very predictable. But in a lot of the scenes it was so uninspired that it should've been as better. The acting was terrible. Don't get me wrong, I don't know what to do with the movie. I could've told more things. I do remember that I was trying to make a bad movie. If you can't get a grip on the movie. What I loved was the chemistry we spent with the characters. I love, I wish I had more. He was good. I hope they could have had a more suspense. There was more for what you should expect."
# '
# 'I thought this movie was a little better. This is some great little movie, but it was the film that made it such a good movie. I've seen a lot of people of these people who love The Lord Of Thunder and the Dark and I think they are better performances than this one. I'm not to blame all of them, and I can take their time to see this. I'm also a fan of those who are talking about what I like, and the only thing worth watching is if they don't think it is a must watch. I had the feeling that this movie is very enjoyable. It's not a film that would be worth seeing. And yes, I was not the fan of this movie. My only concern are the characters. This is a good film, but it's just not a good enough film. The story is too weak for it, the acting is mediocre, the script is mediocre and the direction is poor. I'll give this film a 5."
# '
# 'This is a very dark and suspense film, and I will watch it a lot more. I had no hopes, and I was right. I love this film, as it is the best of films I have seen in a while. I thought it was an extremely well-made film with two main characters. I was thinking about this film too much, but at the same time, I was really excited and I was expecting the audience to be able to enjoy the film. It was very clear what to expect from an ordinary movie. It doesn't try a lot of comedy with his film, and it does not mean the film is as funny as it was. I really couldn't fault the film as much as it is, it just works. The film is actually well worth watching. I had a great time with the actors, as well as the direction. It was one of the first films I have seen. I thought that this was one of the most entertaining movies of all time.I can never imagine what a film was like, and how it ended. It was a good film with a beautiful cinematographer. The ending is also an exciting surprise. I didn't think I would see a second when we decided not to see it. ""I was in for a special treat"" was a great conclusion. But it was a well shot film. I think I can't blame the actors who put it in front of us. And I don't mind it too much for the two main characters. Maybe they should be ashamed. This is a pleasure. It was one of the greatest films ever created. I thought the other actors of them, who I haven't seen since in some movies, did nothing. When I thought to myself about this film, I realized that I wasn't going to get off my nerves. I found the story of an old man with a different age is too much of a surprise. One of the characters in it seemed to be a bunch of misgivings, as the story was supposed to be about an old man, who had a job in a small town. This was nothing less than an excuse for the rest. However, there was no effort to build up the characters in their own way. Someone just said to me if he can make a good film. I thought that the movie was supposed to be good, and I didn't. I gave it a 10 at what it was. I cannot blame'
# 'I had a great time watching this film. I don't know why. I'm sure any of the actors who were in this film were all of them who had a hard time. I don't mind, as they all are. They all seem to be just okay and not as they are. I don't mind the film. When I was 13 I was 12 when I saw this. If I was 13 I can actually say I thought the only thing that made it worth watching. I think this would have made better if it had been more entertaining to watch - I'm just kidding and I don't care about it. I have no problem with the actors. There was nothing wrong with the acting and I can never blame them. I loved the cinematography and the cinematography. But the plot line was predictable as they were trying to find a way to use it. I must have thought so. I can't fault them that I was able to see them as a device for the screenplay. I don't think so. I can go on in the opposite direction. I just hope we don't see them again. If I haven't seen them yet I'll say that. Yes. They can. If I didn't know about them I would have thought to myself. I can only care about this. I was sure we would've heard maybe what the movie was about. I'd have liked to see them have been more of a surprise. They didn't have so much development for the characters. The script was just so convoluted and confusing, it could have been better if they had been using them instead of the plot line. I don't know what so ever expected. The movie wasn't. I don't know exactly what I expected. I don't really know what the hell was. I'm sure it was meant to be. At the beginning of the movie I don't want to know what to think about this movie. I don't know what to recommend to you. I'm sure they are trying to put this picture in the beginning. After some, I thought I could go and see movies like this one. I did not enjoy the ending. I was only glad I did not like to see it. I don't remember this time I did. I can't fault the movie for the ending, but I am not sure and will just like it. I don't know where I can blame the movie, but I think it'
# 'A great movie, if you don't like everything you wish you have then you won't.I can see that all you will be happy with is that you can't just go a little too far.If you don't like this movie then I might have had a bigger disappointment. I'm not a fan of movies this is one to watch to watch, but I found this film to be a nice little girl in the world you are.For me I was wondering all the way through the movie. I just wish that they would have shown a better job from the main characters. I also would go and see this one once, but I didn't want to see anyone else. I thought the movie had a lot of potential and the characters I thought were okay. I thought the movie had something to do with the movie. I thought it was one of the best movies I have ever seen. I would have liked to see more of the characters in the movie."
# '
#
# ---------------
#   Rating: 9
# ---------------
# 'This film is for everybody, the only reason I feel like this film was a very good one. It has some of the worst performances I have ever seen. The film was just too predictable for some reason. One of the things I found the most amusing was the scene that the man was not seeing. The scene that he was having with his ""other guy"" in his fight with the other guy. The scene where he danced at his boss's wife, in the bathroom, and he was screaming ""A man who is going to be on with people"". The scene where he was in his bathing suits on the couch on his cell phone while he is taking a nap. I can't stop thinking about this film. It is very reminiscent of the way the movie shows. It seemed like the acting was good, the way the music was good, the music was good, the acting was good, the screenplay was good. The special effects. The direction of the cinematography was good and very convincing. The direction should have been good and there was some impressive performances by the main characters. It is very impressive. I especially like the use of the sound. I could have made it a great job. The cinematography. I should have given this film an 8 out of 10."
# '
# 'Just like any other movie this was pretty good. The plot was good and the acting was good. I can't blame anyone who else (not that I'm going to blame the actors), although I think that the movie was really funny. When I finally saw it. I realized I had to stop the movie. I thought I was going to see a movie. I was right. I thought it should have kept the story line until I realized that it was supposed to be a comedy at all in all. I'm glad she did it. I just hope she finally has a chance. There are a few moments where I should have enjoyed the whole thing. I don't think I'll ever watch this again. I didn't want to miss anything but I was in it. I just wish I saw this movie. I was wrong! I could go on to watch it. I don't know what it was saying."
# '
# 'I was in my mid twenties on a high school high school course on the beach. I was really pleased by this film. I don't know where to begin. I thought the director's comments, the message, the atmosphere. The acting is the best I've seen. I've seen two other versions of this, especially the 1995 version, and it is the best I've seen. The cinematography is superb. You can't take your eyes off the frame. The score is superb. I thought the camera work was good. I'm sure this was a lot better. I must admit, I'm never sure what I thought of the scene. I'm not a fan of the '70s. I've seen a lot of things from the black-and-white film set, but the one thing I didn't like about this film - the story line. I'm a huge fan of the 'killer killer' of the killer. I didn't think I would've seen any of this when I watched it. I don't understand. I was in this age at the age of 9 years ago and I can't blame it. At least it was only a child movie. It wasn't to be a kids film but that was so much more. I suppose I'm not going to watch anything of this film. I'm glad I did. I liked what the girl did with her face. I was so pleased to see that she was a girl with a child who was so famous. What a great story! I thought she was sexy and I got so attached to the killer. I'm very surprised. I'm not sure if I've missed something. I'm sure we know who she was, but I don't think. I thought she was really a killer. I also thought she wasn't really a killer. I don't know what she was thinking with the ""killer"". I don't know what he was thinking, I don't know who he was. I can only assume this movie was the best one or the worst movie ever made. I don't know where they were trying to be. I was just glad I did, so I didn't like it. I'm glad I did do with this movie. I've no clue what I'm saying. I don't know what you're doing with this movie for the reason, I'm sure I can find this movie. I don't know why but I can'
# 'I am not a fan of a movie or a plot, but I think I loved each one and every time some people watch them. However, I was just looking at the movie. I would recommend the movie for anyone who loves British or Australian, not just for the entertainment. The story is the central story. The characters are very flawed. There is no doubt that they can be the same. The characters are completely believable. They are not just a perfect pair of believable characters who are both realistic and believable. The characters are totally believable. The acting is good. But the special effects are good. The effects and the special effects were good. I was able to see more than one scene to get a glimpse into the characters. The editing is excellent. I cannot fault a good film, but I find it the movie amazing.If you watch a full movie, it's worth picking on. The story is great. This is a movie."
# '
# 'This is a movie that should be watched for everyone else. It is not too much of a spoiler, too much of a spoiler.It's not a fault of the movie, nor does it necessarily detract from the movie itself. But still a true pleasure.This is a great movie. This is a great movie for everyone who likes a good movie and not a great one to enjoy."
# '
#
# ---------------
#   Rating: 10
# ---------------
# 'This is just a movie that will cause people not to like it. The plot is not really that good, but they are. The performances are good, the plot is not terrible enough, there is no doubt the story will be perfect, the acting is good, and the cinematography is good. I have a good time watching this movie once, I thought I would just buy a video of this movie, but even the actors who weren't there in their roles, I think they were wasted. The movie is not too bad for your time, it was nice, and I thought the story would be very good. It was like watching a great horror movie. If you are going for a good movie, don't get me wrong. But it is one that a bad movie is the only thing to make a movie worth seeing. I will have to say the actors who were OK as the police. The movie is very good, I have one reason that this movie is great. Don't get me wrong, it would have been a lot more entertaining. The actors. The movie had a better script and an overall enjoyable cast. The acting. However, it was too much for this movie. There was one scene where the military was shooting on the plane. They were on the plane. I feel like they just don't know what to do with the guns. I don't know what they have any weapons. The sound. I know the sound. As you might be reading the ""Star Wars"", I will say that it took on quite an effort. I do know that the score. It was nice to watch the movie. I am surprised that it didn't get to be the last time I watched. I don't know what the f***er is that did, but I did like this movie. The acting. I don't know what the hell was thinking. I don't know what people are saying, but the plot line. Just don't make the movie. The editing. The acting. All the actors. And the only good thing about it is the computer. I must say, I have an 8 rating system. I thought that the computer was not the best I can think of a computer game. I won't go into detail, I thought the computer was just okay. It was a computer game that was getting up, so I was right. I thought that the movie was a bit more entertaining. This is an enjoyable'
# 'I just don't seem to understand the hate, because it's just so very wrong! The only thing I thought I would like to know about this movie. I was glad I did. I don't know what to say. I'm surprised. But this is my opinion. And the plot. The acting. I'm so disappointed. I could not take my eyes off the film because a man who is a soldier, has a terrible conversation with his wife and a child friend. I have no problem with the movie. But, they are so much more. You are watching this movie on a black television. It is just an action movie. All the characters are just so out of place. I couldn't stop thinking about them. They were so, much more. All they needed, it was not a movie. If there were more to this it would have been a very well made movie. The actors. I'm sure that a good actor will have a career. I could go so far. But, I don't think the film would have the feel of a good movie. I was just disappointed. I was hoping to see if it would have been better, and that was not. The only thing I liked was the music. The only reason I gave it a 1, was that it looked like they should have at least get more screen time to have the plot. But I was wrong instead. This just wasn't a good movie. I don't like it. If you want to see a funny movie then watch this movie. If you want to see an action movie, watch the movie. If you don't like this movie, let me tell you that it's not worth the price of admission. If you want to see an action movie, then there is not a single person who doesn't feel like it! I don't know why she did a bad job playing this role. I don't remember much about her performance. I don't know where the hell she came up with. I don't know what to blame. I don't know where she's going to go, I don't know. I guess she's off screen. I don't know. I'm sure she was thinking about it. I don't know what people would like to expect. I don't know what she's doing. I'm sure she's going to do it. But, and I am sure I saw it. Someone who needs an'
# 'I'll be going to be honest. It probably won't make a lot of sense, but I thought it gave the perfect answers to its characters. There is no doubt about the movie, but it was still a pleasure to watch. It was the perfect ending for a great movie. There is a very well acted and well- crafted story that I didn't want to see again, because I just wish they would have had more to do with the characters. I don't think I will give this movie a bad rating because it is simply an original and beautiful movie. I don't really know if I should have written this book before."
# '
# 'This movie is too long. You are left with an uninteresting ending. There is probably more to follow for the story and the overall length of the movie. It is an early on but it does not feel like a good movie. I would have preferred it to have a lot more time. The only worthwhile thing about this film is the ending. I will just say it was pretty good! Just to show you the film was as much suspense as the book. It does have some things to work with, but these things are questionable. I will not give it any more away. If I just gave it 10, 10 it would be 10/10. I had seen my homework."
# '
# 'As far as the action goes, this is one of the best action sequences I have seen. The visuals are superb, the plot is great. I am not going to watch this movie as anything but entertainment."
# '
